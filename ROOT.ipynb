// %%
tree = TChain("rechitntupler/hits"); tree2 = TChain("trackimpactntupler/impactPoints"); tree.AddFriend(&tree2) ;

// %%
tree2.Add("calo_scan/*") ;
tree.Add("calo_scan/*");

// %%
TCanvas * c2 = new TCanvas("c");
c2->Draw();

// %%
tree.Draw("(PI_positionY-140 ) :(PI_positionX-85 ) : run : run ","PI_positionY > 0 && event < 10","pcolz") ;

// %%
c2->Draw()

// %%
tree.GetEntries()
// Out:
// (long long) 433049
